# %% [markdown]
# #### 透视表是各种电子表格程序和其他数据分析软件中一种常见的数据汇总工具。它根据一个或多个键对数据进行聚合，
# #### 并根据行和列上的分组键将数据分配到各个矩形区域中

# %% [markdown]
# pd.pivot_table()

# %%
df = DataFrame({'male':['男','女','男','女','男','女','男','女','女','男','女','男','女','女','女','男','女','女'],
                'hand':['right','left','left','right','right','left','left','right','right','right','left','right','left','left','right','right','left','left'],
                'height':np.random.randint(160,180,size = 18),'weight':np.random.randint(50,80,size = 18)})
df
# Out:
#    male   hand  height  weight
# 0     男  right     162      74
# 1     女   left     169      72
# 2     男   left     160      61
# 3     女  right     168      73
# 4     男  right     163      70
# 5     女   left     165      77
# 6     男   left     165      56
# 7     女  right     178      72
# 8     女  right     175      51
# 9     男  right     167      78
# 10    女   left     166      50
# 11    男  right     171      62
# 12    女   left     179      69
# 13    女   left     172      76
# 14    女  right     163      74
# 15    男  right     176      68
# 16    女   left     160      56
# 17    女   left     170      78

# %% [markdown]
# 行分组透视图

# %%
pd.pivot_table(df,columns=['male'])
# Out:
# male             女           男
# height  169.545455  166.285714
# weight   68.000000   67.000000

# %%
pd.pivot_table(df,columns=['hand'],aggfunc='sum')
# Out:
# hand    left  right
# height  1506   1523
# weight   595    622

# %% [markdown]
# 列分组透视表

# %%
pd.pivot_table(df,index=['male'])
# Out:
#           height  weight
# male
# 女     169.545455    68.0
# 男     166.285714    67.0

# %%
pd.pivot_table(df,index=['hand'])
# Out:
#            height     weight
# hand
# left   167.333333  66.111111
# right  169.222222  69.111111

# %% [markdown]
# 行列分组的透视表

# %%
# 透视表：根据特定条件进行分组计算，查找数据，进行计算
pd.pivot_table(df,index=['hand'],columns=['male'],aggfunc='min')
# Out:
#       height      weight
# male       女    男      女   男
# hand
# left     160  160     50  56
# right    163  162     51  62

# %% [markdown]
# #### 交叉表是一种用于计算分组频率的特殊透视图,对数据进行汇总

# %% [markdown]
# pd.crosstab(index,colums)

# %%
import numpy as np

import pandas as pd

# %%
nd = np.random.randint(0,10000,size = 1000)

np.save('./data.npy',nd)

# %%
np.load('./data.npy')
# Out:
# array([9884, 4021, 7244, 6289, 5521, 5433,  766, 1302, 3697,  305, 6018,
#        9929, 1845, 2332,  364, 7616, 3202, 8136, 3479, 5769, 8859, 5739,
#        6799, 2202, 2781, 8089, 9039, 4839, 7551,  729, 7849,  915,  375,
#        5587, 8710, 8751, 9723, 8194, 5782, 3086,   35, 3603, 6709, 7482,
#        8113, 5922, 5876,  507, 9536, 8392, 8860, 1164, 8086, 2035, 4913,
#        2250, 7663, 6886, 8338, 8877, 5744, 5882, 6616, 7630, 7791, 9023,
#        9322, 6110, 6225, 2921,  762, 8985, 3789, 3334, 8365, 2208, 1138,
#        8713, 2656, 2478, 8356, 2883, 6206,   57, 2159, 9880, 4845, 4603,
#        4945, 4221, 3493,  875, 7725, 5389, 9370, 7810, 8528, 2559, 4533,
#        2844, 3807, 7331, 3415, 7729, 1134, 2190, 4842, 7832, 3990,  201,
#        9562, 2836, 6899, 9964, 6239, 2000, 8220, 8209,  196, 5473, 6620,
#        9034, 8769, 8305, 6697, 9210, 2413,  991, 5731, 2885,  955,  788,
#        6129, 1607, 4728,  952,  843, 7578, 6694,  265, 5115, 6529, 3660,
#        9842,  957, 5653, 6740, 8758, 4353, 7268, 2225, 6003,   93, 8089,
#         704,  493, 8192, 1716, 5762,  749, 2674, 6274, 2442, 1582, 1592,
#        8978, 3303, 1890, 6110, 4846, 4960, 5089,  573,  632, 4117, 6396,
#        5717, 6883, 1936, 4223, 7481, 9083,  181, 6052,  504, 9096, 7067,
#        3908, 6089, 1293,  300, 6395, 6730, 7482, 6932, 4442, 2979, 7617,
#        3024, 8991,  255, 8272, 1701, 5210,  636, 6667, 9459, 7026, 9317,
#        2216, 5954, 7054, 6865, 4069, 2073, 8790, 7842, 7250, 5627, 1727,
#        9239, 6230, 9626, 2310, 8573, 9540, 8942, 4073, 6006, 3708, 9571,
#         949, 7725, 8794, 6516, 4251, 6294, 9666, 5140, 1756,  207, 2962,
#        4333,  812, 7506, 4515,   45, 4901, 2334, 9402, 9971, 7524])

# %%
t = np.load('./cancer_true.npy')
p = np.load('./cancer_predict.npy')

display(t,p)
# Out:
# array(['B', 'M', 'M', 'B', 'M', 'B', 'B', 'B', 'M', 'B', 'B', 'M', 'M',
#        'B', 'B', 'M', 'B', 'B', 'B', 'B', 'B', 'B', 'M', 'M', 'B', 'B',
#        'B', 'M', 'M', 'M', 'M', 'B', 'B', 'B', 'M', 'B', 'B', 'M', 'B',
#        'B', 'B', 'B', 'B', 'B', 'B', 'B', 'M', 'M', 'B', 'B', 'B', 'M',
#        'M', 'B', 'B', 'B', 'B'], dtype=object)
# array(['B', 'M', 'M', 'B', 'M', 'B', 'B', 'B', 'M', 'B', 'B', 'M', 'M',
#        'B', 'B', 'M', 'B', 'B', 'B', 'B', 'B', 'B', 'M', 'M', 'B', 'B',
#        'B', 'M', 'B', 'B', 'M', 'B', 'B', 'B', 'M', 'B', 'B', 'M', 'B',
#        'B', 'B', 'B', 'B', 'B', 'B', 'B', 'M', 'M', 'B', 'B', 'B', 'M',
#        'M', 'B', 'M', 'M', 'B'], dtype=object)

# %%
# index ----行
# columns ----列
pd.crosstab(index = t,columns=p,colnames=['Predict'],rownames=['True'],margins=True)
# Out:
# Predict   B   M  All
# True
# B        36   2   38
# M         2  17   19
# All      38  19   57

# %%
from pandas import Series,DataFrame

# %%
df = DataFrame({'True':t,'Predict':p})
df
# Out:
#    True Predict
# 0     B       B
# 1     M       M
# 2     M       M
# 3     B       B
# 4     M       M
# 5     B       B
# 6     B       B
# 7     B       B
# 8     M       M
# 9     B       B
# 10    B       B
# 11    M       M
# 12    M       M
# 13    B       B
# 14    B       B
# 15    M       M
# 16    B       B
# 17    B       B
# 18    B       B
# 19    B       B
# 20    B       B
# 21    B       B
# 22    M       M
# 23    M       M
# 24    B       B
# 25    B       B
# 26    B       B
# 27    M       M
# 28    M       B
# 29    M       B
# 30    M       M
# 31    B       B
# 32    B       B
# 33    B       B
# 34    M       M
# 35    B       B
# 36    B       B
# 37    M       M
# 38    B       B
# 39    B       B
# 40    B       B
# 41    B       B
# 42    B       B
# 43    B       B
# 44    B       B
# 45    B       B
# 46    M       M
# 47    M       M
# 48    B       B
# 49    B       B
# 50    B       B
# 51    M       M
# 52    M       M
# 53    B       B
# 54    B       M
# 55    B       M
# 56    B       B

# %%
pd.crosstab(df['True'],df['Predict'])
# Out:
# Predict   B   M
# True
# B        36   2
# M         2  17
